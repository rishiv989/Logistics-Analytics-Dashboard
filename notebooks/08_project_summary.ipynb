# %% [markdown]
# DATASET
# 99,441 orders
# Brazilian e-commerce dataset
# 2016–2018

# %% [markdown]
# Key Business Findings
# 1. Top 3 states generate 62.53% of revenue.
# 2. Fast deliveries average 4.42 reviews.
# 3. Very slow deliveries average 3.10 reviews.
# 4. AL, MA, SE have highest delay rates.
# 5. Smaller states generate highest revenue per order.

# %% [markdown]
# Machine Learning Findings
#
# Baseline Logistic Regression:
# ROC-AUC = 0.56
#
# Improved Random Forest:
# ROC-AUC = 0.69
#
# Feature Engineering improved predictive power.
